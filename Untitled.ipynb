# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('amazon.csv')
df
# Out:
#                                 Uniq Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  Brand Name  Asin  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...         NaN   NaN
# 1      Electronic Snap Circuits Mini Kits Classpack, ...         NaN   NaN
# 2      3Doodler Create Flexy 3D Printing Filament Ref...         NaN   NaN
# 3      Guillow Airplane Design Studio with Travel Cas...         NaN   NaN
# 4                       Woodstock- Collage 500 pc Puzzle         NaN   NaN
# ...

# %%
df2=pd.read_csv('amazon_reviews.csv')
df2
# Out:
#                              Uniq Id            Crawl Timestamp  \
# 0   10d8b81dc693db8a3f92e19254525d53  2020-03-17 02:32:10 +0000
# 1   31ef1ee4961d3fcff33e363edd7677eb  2020-03-17 02:32:10 +0000
# 2   6943e517922b051cbec496be32fbb57f  2020-03-17 02:32:10 +0000
# 3   6778c794e6ac7112981d4ebb239d6826  2020-03-17 02:32:10 +0000
# 4   2335a28ae24db3b2191080bfd98a86e0  2020-03-17 02:32:10 +0000
# 5   33bdd85b5bfc5a9ed528b2182d393e1a  2020-03-17 02:32:10 +0000
# 6   afdd2760b29787829eca03c79baa794a  2020-03-17 02:32:10 +0000
# 7   f1d50311e1659471c4bf46ba1ceb5aa6  2020-03-17 02:32:10 +0000
# 8   3083f245a5bcee9c346b946ba7911ef5  2020-03-17 02:32:10 +0000
# 9   17f3ae36d170e602bfe52dca60355ab9  2020-03-17 02:32:10 +0000
# 10  d39d2dada314001ac85086c902331d5d  2020-03-17 02:44:43 +0000
# 11  cfdd4cd3b684f3e60366eab64767dd47  2020-03-17 02:44:43 +0000
# 12  2ec6117d17fd8b91f61c885de1a35120  2020-03-17 02:44:43 +0000
# 13  55aaa480e75bb9dc197db7e279456b01  2020-03-17 02:44:43 +0000
# ...

# %%
df2= df2.drop(['Asin', 'Category', 'Product Description'], axis = 1)

# %%
df.join(df2.set_index('Uniq Id'), on='Uniq Id')
# Out:
#                                 Uniq Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  Brand Name  Asin  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...         NaN   NaN
# 1      Electronic Snap Circuits Mini Kits Classpack, ...         NaN   NaN
# 2      3Doodler Create Flexy 3D Printing Filament Ref...         NaN   NaN
# 3      Guillow Airplane Design Studio with Travel Cas...         NaN   NaN
# 4                       Woodstock- Collage 500 pc Puzzle         NaN   NaN
# ...

# %%
print(df.columns)
print(df.shape)
print(df.info)
# Out:
# Index(['Uniq Id', 'Product Name', 'Brand Name', 'Asin', 'Category',
#        'Upc Ean Code', 'List Price', 'Selling Price', 'Quantity',
#        'Model Number', 'About Product', 'Product Specification',
#        'Technical Details', 'Shipping Weight', 'Product Dimensions', 'Image',
#        'Variants', 'Sku', 'Product Url', 'Stock', 'Product Details',
#        'Dimensions', 'Color', 'Ingredients', 'Direction To Use',
#        'Is Amazon Seller', 'Size Quantity Variant', 'Product Description'],
#       dtype='object')
# (10002, 28)
# <bound method DataFrame.info of                                 Uniq Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# ...

# %%
df.isnull()
# Out:
#        Uniq Id  Product Name  Brand Name  Asin  Category  Upc Ean Code  \
# 0        False         False        True  True     False          True
# 1        False         False        True  True     False          True
# 2        False         False        True  True     False          True
# 3        False         False        True  True     False          True
# 4        False         False        True  True     False          True
# ...        ...           ...         ...   ...       ...           ...
# 9997     False         False        True  True     False          True
# 9998     False         False        True  True     False          True
# 9999     False         False        True  True     False          True
# 10000    False         False        True  True     False          True
# 10001    False         False        True  True     False          True
#
#        List Price  Selling Price  Quantity  Model Number  ...  Product Url  \
# ...

# %%
df= df.drop(['Direction To Use', 'Quantity', 'Color', 'Asin', 'List Price', 'Brand Name', 'Upc Ean Code', 'Size Quantity Variant', 'Dimensions'],axis=1)
df
# Out:
#                                 Uniq Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
# 1      Electronic Snap Circuits Mini Kits Classpack, ...
# 2      3Doodler Create Flexy 3D Printing Filament Ref...
# 3      Guillow Airplane Design Studio with Travel Cas...
# 4                       Woodstock- Collage 500 pc Puzzle
# ...                                                  ...
# 9997   Remedia Publications REM536B Money Activity Bo...
# ...

# %%
Category=[]
for i in range(len(df.Category)):
    for x in df.Category[i].split('|'):
        if x not in Category:
            Category.append(x)  

len(Category)
for x in Category:
    df[x] = 0
for i in range(len(df.Category)):
    for x in df.Category[i].split('|'):
        df[x][i]=1
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-89ceefe1770f> in <module>
#       1 Category=[]
#       2 for i in range(len(df.Category)):
# ----> 3     for x in df.Category[i].split('|'):
#       4         if x not in Category:
#       5             Category.append(x)
#
# AttributeError: 'float' object has no attribute 'split'
